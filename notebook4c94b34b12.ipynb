# %% [markdown]
# # Questions

# %% [markdown]
# # Import Libraries

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# # Import Data

# %%
df = pd.read_csv('../input/telco-customer-churn/WA_Fn-UseC_-Telco-Customer-Churn.csv', sep = "," ,encoding = "utf-8")

# %%
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %% [markdown]
# # Basic methods in Pandas

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.tail(5)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
df.sample(10)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 3685  7244-QWYHG    Male              0     Yes         No      50
# 3148  2452-SNHFZ  Female              0      No         No      47
# 1890  6770-XUAGN  Female              0     Yes        Yes       1
# 1545  5193-QLVZB    Male              0      No         No      63
# 2510  3707-GNWHM    Male              0      No         No       1
# 525   0750-EBAIU    Male              0      No         No      52
# 4800  9300-AGZNL    Male              1      No         No       1
# 3380  5178-LMXOP    Male              1     Yes         No       1
# 826   3643-AHCFP    Male              1     Yes         No       7
# 5303  9839-ETQOE    Male              0      No        Yes      43
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 3685           No  No phone service             DSL                  Yes  ...
# ...

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df.columns.to_list()
# Out:
# ['customerID',
#  'gender',
#  'SeniorCitizen',
#  'Partner',
#  'Dependents',
#  'tenure',
#  'PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod',
#  'MonthlyCharges',
#  'TotalCharges',
#  'Churn']

# %%
df.InternetService
# Out:
# 0               DSL
# 1               DSL
# 2               DSL
# 3               DSL
# 4       Fiber optic
#            ...
# 7038            DSL
# 7039    Fiber optic
# 7040            DSL
# 7041    Fiber optic
# 7042    Fiber optic
# Name: InternetService, Length: 7043, dtype: object

# %% [markdown]
# **another method**

# %%
df.isnull()
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0          False   False          False    False       False   False
# 1          False   False          False    False       False   False
# 2          False   False          False    False       False   False
# 3          False   False          False    False       False   False
# 4          False   False          False    False       False   False
# ...          ...     ...            ...      ...         ...     ...
# 7038       False   False          False    False       False   False
# 7039       False   False          False    False       False   False
# 7040       False   False          False    False       False   False
# 7041       False   False          False    False       False   False
# 7042       False   False          False    False       False   False
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# ...

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.MonthlyCharges.describe()
# Out:
# count    7043.000000
# mean       64.761692
# std        30.090047
# min        18.250000
# 25%        35.500000
# 50%        70.350000
# 75%        89.850000
# max       118.750000
# Name: MonthlyCharges, dtype: float64

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
df.describe(include='object')
# Out:
#         customerID gender Partner Dependents PhoneService MultipleLines  \
# count         7043   7043    7043       7043         7043          7043
# unique        7043      2       2          2            2             3
# top     7590-VHVEG   Male      No         No          Yes            No
# freq             1   3555    3641       4933         6361          3390
#
#        InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# count             7043           7043         7043             7043
# unique               3              3            3                3
# top        Fiber optic             No           No               No
# freq              3096           3498         3088             3095
#
#        TechSupport StreamingTV StreamingMovies        Contract  \
# count         7043        7043            7043            7043
# unique           3           3               3               3
# top             No          No              No  Month-to-month
# ...

# %%
df.MultipleLines.unique()
# Out:
# array(['No phone service', 'No', 'Yes'], dtype=object)

# %%
df.Contract.unique()
# Out:
# array(['Month-to-month', 'One year', 'Two year'], dtype=object)

# %%
sns.kdeplot(data=df, x="MonthlyCharges")
# Out:
# <Axes: xlabel='MonthlyCharges', ylabel='Density'>

# %%
sns.kdeplot(data=df, x="tenure")
# Out:
# <Axes: xlabel='tenure', ylabel='Density'>

# %%
sns.kdeplot(data=df,x="SeniorCitizen")
# Out:
# <Axes: xlabel='SeniorCitizen', ylabel='Density'>

# %%
sns.kdeplot(data=df, y="MonthlyCharges")
# Out:
# <Axes: xlabel='Density', ylabel='MonthlyCharges'>

# %%
df= pd.read_csv('../input/telco-customer-churn/WA_Fn-UseC_-Telco-Customer-Churn.csv', sep = "," ,encoding = "utf-8")

# %%
sns.histplot(data=df, x="MonthlyCharges", hue="Contract", multiple="stack")
# Out:
# <Axes: xlabel='MonthlyCharges', ylabel='Count'>

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
sns.displot(data=df, x='MonthlyCharges', hue="Contract", multiple="stack", kind="kde")
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(data=df, x="MonthlyCharges", col="Contract")
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.kdeplot(data=df, x="MonthlyCharges", hue="Contract")
# Out:
# <Axes: xlabel='MonthlyCharges', ylabel='Density'>

# %%
sns.displot(data=df, x="MonthlyCharges", col="Contract" , kind = "kde")
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(data=df, x="MonthlyCharges", col="Churn" )
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(data=df, x="Contract", col="Churn" )
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(data=df, x="MonthlyCharges",hue = "Contract" , col="Churn" , kind = "kde")
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df_2= df.copy()

# %% [markdown]
# **to test the effect of gender on churn**

# %%
df_2['Churn'].value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
df_2['Churn'].replace("No" , 0 , inplace = True)
df_2['Churn'].replace("Yes" , 1 , inplace = True)

# %%
df_2['Churn']=pd.to_numeric

# %%
df_2['gender'].value_counts()
# Out:
# Male      3555
# Female    3488
# Name: gender, dtype: int64

# %%
df_2['gender'].replace("No" , "Female"  , inplace = True)
df_2['gender'].replace("Yes" , "Male" , inplace = True)

# %%
df_2.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
sns.countplot(data=df_2, x="Churn", hue="gender")
# Out:
# <Axes: xlabel='Churn', ylabel='count'>

# %%
sns.countplot(data=df_2, x="gender", hue="Churn")
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
df_2.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df["gender"] = pd.to_numeric(df["gender"], errors="coerce")

# %%
df_2['Partner'].value_counts()
# Out:
# No     3641
# Yes    3402
# Name: Partner, dtype: int64

# %%
df_2['Partner'].replace("No" , 0 , inplace = True)
df_2['Partner'].replace("Yes" , 1 , inplace = True)

# %%
sns.countplot(data=df_2, x="Churn", hue="Partner")
# Out:
# <Axes: xlabel='Churn', ylabel='count'>

# %%
sns.countplot(data=df_2, x="Partner", hue="Churn")
# Out:
# <Axes: xlabel='Partner', ylabel='count'>

# %% [markdown]
# # Other Pandas Methods

# %%
df = pd.read_csv('../input/telco-customer-churn/WA_Fn-UseC_-Telco-Customer-Churn.csv', sep = "," ,encoding = "utf-8")

# %%
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df['PaymentMethod'].value_counts()
# Out:
# Electronic check             2365
# Mailed check                 1612
# Bank transfer (automatic)    1544
# Credit card (automatic)      1522
# Name: PaymentMethod, dtype: int64

# %%
df['InternetService'].value_counts()
# Out:
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: InternetService, dtype: int64

# %%
df['MultipleLines'].value_counts()
# Out:
# No                  3390
# Yes                 2971
# No phone service     682
# Name: MultipleLines, dtype: int64

# %%
df['tenure'].value_counts()
# Out:
# 1     613
# 72    362
# 2     238
# 3     200
# 4     176
#      ...
# 28     57
# 39     56
# 44     51
# 36     50
# 0      11
# Name: tenure, Length: 73, dtype: int64

# %%
df.groupby(["InternetService"]).sum()
# Out:
# /tmp/ipykernel_20/4015154412.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(["InternetService"]).sum()
#                  SeniorCitizen  tenure  MonthlyCharges
# InternetService
# DSL                        259   79461       140665.35
# Fiber optic                831  101914       283284.40
# No                          52   46615        32166.85

# %%
df.groupby(["Churn"]).sum()
# Out:
# /tmp/ipykernel_20/4138740351.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(["Churn"]).sum()
#        SeniorCitizen  tenure  MonthlyCharges
# Churn
# No               666  194387       316985.75
# Yes              476   33603       139130.85

# %%
df.groupby(['Churn']).sum().sort_values("tenure" , ascending= False)
# Out:
# /tmp/ipykernel_20/2450726590.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['Churn']).sum().sort_values("tenure" , ascending= False)
#        SeniorCitizen  tenure  MonthlyCharges
# Churn
# No               666  194387       316985.75
# Yes              476   33603       139130.85

# %%
df.groupby(['Churn']).sum().sort_values("tenure" , ascending= False)[["tenure"]].head(10)
# Out:
# /tmp/ipykernel_20/3692410736.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['Churn']).sum().sort_values("tenure" , ascending= False)[["tenure"]].head(10)
#        tenure
# Churn
# No     194387
# Yes     33603

# %%
df['Churn'].replace("No" , 0 , inplace = True)
df['Churn'].replace("Yes" , 1 , inplace = True)

# %%
df['Churn']=pd.to_numeric(df['Churn'])

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df.groupby(['Churn' , "Contract"]).sum()[["MonthlyCharges"]].head(20)
# Out:
# /tmp/ipykernel_20/4193069855.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['Churn' , "Contract"]).sum()[["MonthlyCharges"]].head(20)
#                       MonthlyCharges
# Churn Contract
# 0     Month-to-month       136447.05
#       One year              81698.15
#       Two year              98840.55
# 1     Month-to-month       120847.10
#       One year              14118.45
#       Two year               4165.30

# %%
df.groupby(['Churn' , "Contract"]).sum()[["tenure"]].head(20)
# Out:
# /tmp/ipykernel_20/2138687236.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['Churn' , "Contract"]).sum()[["tenure"]].head(20)
#                       tenure
# Churn Contract
# 0     Month-to-month   46694
#       One year         54468
#       Two year         93225
# 1     Month-to-month   23198
#       One year          7464
#       Two year          2941

# %%
df.groupby(['Churn' , "gender"]).sum()[["MonthlyCharges"]].head(20)
# Out:
# /tmp/ipykernel_20/2234420500.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['Churn' , "gender"]).sum()[["MonthlyCharges"]].head(20)
#               MonthlyCharges
# Churn gender
# 0     Female       157183.85
#       Male         159801.90
# 1     Female        70248.55
#       Male          68882.30

# %%
df.groupby(['Churn' , "Partner"]).sum()[["MonthlyCharges"]]
# Out:
# /tmp/ipykernel_20/4293613324.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['Churn' , "Partner"]).sum()[["MonthlyCharges"]]
#                MonthlyCharges
# Churn Partner
# 0     No            139800.60
#       Yes           177185.15
# 1     No             85741.15
#       Yes            53389.70

# %%
df.groupby(['Churn' , "TechSupport"]).sum()[["MonthlyCharges"]]
# Out:
# /tmp/ipykernel_20/3584078119.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['Churn' , "TechSupport"]).sum()[["MonthlyCharges"]]
#                            MonthlyCharges
# Churn TechSupport
# 0     No                        148329.75
#       No internet service        29865.25
#       Yes                       138790.75
# 1     No                        110709.80
#       No internet service         2301.60
#       Yes                        26119.45

# %%
df.groupby(['Churn' , "Dependents"]).sum()[["MonthlyCharges"]]
# Out:
# /tmp/ipykernel_20/491472256.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['Churn' , "Dependents"]).sum()[["MonthlyCharges"]]
#                   MonthlyCharges
# Churn Dependents
# 0     No               215148.35
#       Yes              101837.40
# 1     No               115376.50
#       Yes               23754.35

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df_3= df[['Partner', 'TotalCharges', 'MonthlyCharges', 'PaymentMethod', 'MultipleLines','Contract']]
df_3.head(10)
# Out:
#   Partner TotalCharges  MonthlyCharges              PaymentMethod  \
# 0     Yes        29.85           29.85           Electronic check
# 1      No       1889.5           56.95               Mailed check
# 2      No       108.15           53.85               Mailed check
# 3      No      1840.75           42.30  Bank transfer (automatic)
# 4      No       151.65           70.70           Electronic check
# 5      No        820.5           99.65           Electronic check
# 6      No       1949.4           89.10    Credit card (automatic)
# 7      No        301.9           29.75               Mailed check
# 8     Yes      3046.05          104.80           Electronic check
# 9      No      3487.95           56.15  Bank transfer (automatic)
#
#       MultipleLines        Contract
# 0  No phone service  Month-to-month
# 1                No        One year
# 2                No  Month-to-month
# 3  No phone service        One year
# 4                No  Month-to-month
# ...

# %%
df4=df.copy()

# %%
df4.drop_duplicates()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df4.drop_duplicates(subset="customerID")
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df4.drop_duplicates(subset="customerID")
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df4.drop_duplicates(subset="InternetService")
# Out:
#     customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0   7590-VHVEG  Female              0     Yes         No       1           No
# 4   9237-HQITU  Female              0      No         No       2          Yes
# 11  7469-LKBCI    Male              0      No         No      16          Yes
#
#        MultipleLines InternetService       OnlineSecurity  ...  \
# 0   No phone service             DSL                   No  ...
# 4                 No     Fiber optic                   No  ...
# 11                No              No  No internet service  ...
#
#        DeviceProtection          TechSupport          StreamingTV  \
# 0                    No                   No                   No
# 4                    No                   No                   No
# 11  No internet service  No internet service  No internet service
#
#         StreamingMovies        Contract PaperlessBilling  \
# 0                    No  Month-to-month              Yes
# ...

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df4['TotalCharges']
# Out:
# 0         29.85
# 1        1889.5
# 2        108.15
# 3       1840.75
# 4        151.65
#          ...
# 7038     1990.5
# 7039     7362.9
# 7040     346.45
# 7041      306.6
# 7042     6844.5
# Name: TotalCharges, Length: 7043, dtype: object

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df4[10:]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 10    9763-GRSKD    Male              0     Yes        Yes      13
# 11    7469-LKBCI    Male              0      No         No      16
# 12    8091-TTVAX    Male              0     Yes         No      58
# 13    0280-XJGEX    Male              0      No         No      49
# 14    5129-JLPIS    Male              0      No         No      25
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 10            Yes                No             DSL                  Yes  ...
# ...

# %%
df4[1:10]
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
# 5  9305-CDSKC  Female              0      No         No       8          Yes
# 6  1452-KIOVK    Male              0      No        Yes      22          Yes
# 7  6713-OKOMC  Female              0      No         No      10           No
# 8  7892-POOKP  Female              0     Yes         No      28          Yes
# 9  6388-TABGU    Male              0      No        Yes      62          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 1                No             DSL            Yes  ...              Yes
# ...

# %%
df4.iloc[10:20 , :2]
# Out:
#     customerID  gender
# 10  9763-GRSKD    Male
# 11  7469-LKBCI    Male
# 12  8091-TTVAX    Male
# 13  0280-XJGEX    Male
# 14  5129-JLPIS    Male
# 15  3655-SNQYZ  Female
# 16  8191-XWSZG  Female
# 17  9959-WOFKT    Male
# 18  4190-MFLUW  Female
# 19  4183-MYFRB  Female

# %%
df4.iloc[40:100 , [1,3,6,7,-1]]
# Out:
#     gender Partner PhoneService     MultipleLines  Churn
# 40    Male     Yes          Yes                No      0
# 41  Female     Yes          Yes               Yes      0
# 42  Female     Yes          Yes                No      0
# 43  Female      No          Yes               Yes      0
# 44  Female     Yes          Yes               Yes      0
# 45  Female      No          Yes               Yes      0
# 46    Male      No          Yes                No      0
# 47  Female      No          Yes                No      1
# 48    Male      No          Yes               Yes      0
# 49  Female     Yes          Yes               Yes      0
# 50  Female      No          Yes               Yes      0
# 51  Female      No          Yes                No      1
# 52  Female     Yes          Yes               Yes      0
# 53  Female     Yes          Yes               Yes      1
# 54  Female     Yes          Yes                No      0
# ...

# %%
df4.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df4['TotalCharges'] = pd.to_numeric(df4['TotalCharges'], errors='coerce')

# %%
df4.loc[:10,['gender',"gender"]]
# Out:
#     gender  gender
# 0   Female  Female
# 1     Male    Male
# 2     Male    Male
# 3     Male    Male
# 4   Female  Female
# 5   Female  Female
# 6     Male    Male
# 7   Female  Female
# 8   Female  Female
# 9     Male    Male
# 10    Male    Male

# %%
df4.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df4['InternetService'].value_counts()
# Out:
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: InternetService, dtype: int64

# %%
df4['InternetService']=="Fiber optic"
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 7038    False
# 7039     True
# 7040    False
# 7041     True
# 7042     True
# Name: InternetService, Length: 7043, dtype: bool

# %%
df4[(df4['MonthlyCharges'] >50) & (df4['TotalCharges'] > 220)]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 1     5575-GNVDE    Male              0      No         No      34
# 5     9305-CDSKC  Female              0      No         No       8
# 6     1452-KIOVK    Male              0      No        Yes      22
# 8     7892-POOKP  Female              0     Yes         No      28
# 9     6388-TABGU    Male              0      No        Yes      62
# ...          ...     ...            ...     ...        ...     ...
# 7036  7750-EYXWZ  Female              0      No         No      12
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 1             Yes                No             DSL            Yes  ...
# ...

# %%
df4[(df4['gender'] == "Male") & (df4['tenure'] > 50) & (df4["InternetService"] == "DSL")]
# Out:
#       customerID gender  SeniorCitizen Partner Dependents  tenure  \
# 9     6388-TABGU   Male              0      No        Yes      62
# 28    5248-YGIJN   Male              0     Yes         No      72
# 48    7639-LIAYI   Male              0      No         No      52
# 62    0526-SXDJP   Male              0     Yes         No      72
# 92    7233-PAHHL   Male              0     Yes        Yes      66
# ...          ...    ...            ...     ...        ...     ...
# 6897  2363-BJLSL   Male              0      No         No      62
# 6956  2451-YMUXS   Male              1      No         No      67
# 6995  7164-BPTUT   Male              0      No        Yes      57
# 7007  2274-XUATA   Male              1     Yes         No      72
# 7031  3605-JISKB   Male              1     Yes         No      55
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 9             Yes                No             DSL            Yes  ...
# ...

# %%
#to remove all raws with null values
#data is not iincluded no null values
df5=df.dropna(inplace = True)

# %%
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df.drop(2)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# 5     9305-CDSKC  Female              0      No         No       8
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df.drop("gender",axis=1)
# Out:
#       customerID  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     7590-VHVEG              0     Yes         No       1           No
# 1     5575-GNVDE              0      No         No      34          Yes
# 2     3668-QPYBK              0      No         No       2          Yes
# 3     7795-CFOCW              0      No         No      45           No
# 4     9237-HQITU              0      No         No       2          Yes
# ...          ...            ...     ...        ...     ...          ...
# 7038  6840-RESVB              0     Yes        Yes      24          Yes
# 7039  2234-XADUH              0     Yes        Yes      72          Yes
# 7040  4801-JZAZL              0     Yes        Yes      11           No
# 7041  8361-LTMKD              1     Yes         No       4          Yes
# 7042  3186-AJIEK              0      No         No      66          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# ...

# %%
df.drop(["gender","tenure"],axis=1)
# Out:
#       customerID  SeniorCitizen Partner Dependents PhoneService  \
# 0     7590-VHVEG              0     Yes         No           No
# 1     5575-GNVDE              0      No         No          Yes
# 2     3668-QPYBK              0      No         No          Yes
# 3     7795-CFOCW              0      No         No           No
# 4     9237-HQITU              0      No         No          Yes
# ...          ...            ...     ...        ...          ...
# 7038  6840-RESVB              0     Yes        Yes          Yes
# 7039  2234-XADUH              0     Yes        Yes          Yes
# 7040  4801-JZAZL              0     Yes        Yes           No
# 7041  8361-LTMKD              1     Yes         No          Yes
# 7042  3186-AJIEK              0      No         No          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0     No phone service             DSL             No          Yes
# ...

# %%
df6=df[["MultipleLines","PhoneService"]]

# %%
df6
# Out:
#          MultipleLines PhoneService
# 0     No phone service           No
# 1                   No          Yes
# 2                   No          Yes
# 3     No phone service           No
# 4                   No          Yes
# ...                ...          ...
# 7038               Yes          Yes
# 7039               Yes          Yes
# 7040  No phone service           No
# 7041               Yes          Yes
# 7042                No          Yes
#
# [7043 rows x 2 columns]

# %%
df7=df.copy()

# %%
df7.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
#replace No phone service in 'MultipleLines' with no
df7.loc["No phone service", 'MultipleLines'] = "NO"

# %%
df7.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female            0.0     Yes         No     1.0           No
# 1  5575-GNVDE    Male            0.0      No         No    34.0          Yes
# 2  3668-QPYBK    Male            0.0      No         No     2.0          Yes
# 3  7795-CFOCW    Male            0.0      No         No    45.0           No
# 4  9237-HQITU  Female            0.0      No         No     2.0          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...
